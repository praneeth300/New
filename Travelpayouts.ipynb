# %%
import pandas as pd
import requests
df = pd.read_csv("DDD.csv")

# %%
df
# Out:
#    Code
# 0   AGR
# 1   DIB
# 2   HYD
# 3   BHJ
# 4   HBX
# ..  ...
# 79  IXS
# 80  CNN
# 81  GOI
# 82  AMD
# 83  TIR
#
# [84 rows x 1 columns]

# %%
import pandas as pd
import requests
df = pd.read_csv("DDD.csv")
data=[]
for j in df['Code']:
  print(j)
  for i in range(13,31):
    url='http://map.aviasales.ru/prices.json?origin_iata='+j+'&period=2021-04-'+str(i)+':season&direct=true&one_way=true&no_visa=true&schengen=true&need_visa=true&locale=ru&min_trip_duration_in_days=13&max_trip_duration_in_days=15'
    response = requests.request("GET", url).json()
    data.append(response)
# Out:
# AGR
# DIB
# HYD
# BHJ
# HBX
# IXD
# JDH
# UDR
# PAT
# IXR
# GAU
# IXC
# IXA
# BBI
# IXM
# DHM
# STV
# VNS
# IXU
# KUU
# BHO
# CDP
# IXE
# BUP
# PNQ
# PGH
# DEL
# IMF
# GOP
# IXP
# JSA
# BLR
# MAA
# TEZ
# CJB
# RJA
# SLV
# BOM
# IXI
# TCR
# VTZ
# SHL
# DED
# IXG
# GWL
# COK
# SXR
# TRV
# ATQ
# CCU
# NDC
# AGX
# JAI
# RAJ
# DIU
# TRZ
# DBR
# AJL
# JLR
# CCJ
# DMU
# BEK
# LKO
# RPR
# JGA
# VGA
# IXZ
# BHU
# IXJ
# GAY
# BDQ
# IXB
# HJR
# PNY
# NAG
# IDR
# JRH
# KNU
# IXL
# IXS
# CNN
# GOI
# AMD
# TIR

# %%
len(data)
# Out:
# 1512

# %%
data
# Out:
# [[{'actual': True,
#    'airline': '6E',
#    'created_at': 1617984996,
#    'depart_date': '2021-04-16',
#    'destination': 'BOM',
#    'distance': 0,
#    'found_at': '2021-04-09T16:16:36',
#    'gate': 'IndiGo',
#    'number_of_changes': 1,
#    'origin': 'AGR',
#    'return_date': None,
#    'show_to_affiliates': False,
#    'trip_class': 0,
#    'ttl': 1618157796,
#    'value': 4981.0},
#   {'actual': True,
#    'airline': '6E',
#    'created_at': 1618055013,
#    'depart_date': '2021-04-11',
#    'destination': 'MAA',
#    'distance': 0,
#    'found_at': '2021-04-10T11:43:33',
#    'gate': 'Mytrip.com',
#    'number_of_changes': 1,
#    'origin': 'AGR',
#    'return_date': None,
#    'show_to_affiliates': False,
#    'trip_class': 0,
#    'ttl': 1618227813,
#    'value': 7559.0},
#   {'actual': True,
#    'airline': 'AF',
#    'created_at': 1618163853,
#    'depart_date': '2021-04-20',
#    'destination': 'MOW',
#    'distance': 0,
#    'found_at': '2021-04-11T17:57:33',
# ...

# %%
price=[]
airline=[]
destination=[]
depart_date=[]
origin=[]
found_at=[]
via=[]
ttl=[]
created=[]
for i in data:
  #if len(i)>50:
  for j in i:
    price.append(j["value"])
    airline.append(j["airline"])
    destination.append(j["destination"])
    depart_date.append(j["depart_date"])
    found_at.append(j["found_at"])
    origin.append(j["origin"])
    via.append(j["number_of_changes"])

# %%
import pandas as pd
df=pd.DataFrame(price,columns=["Price"])
df["Airline"]=airline
df["Destination"]=destination
df["Depart_Date"]=depart_date
df["Time"]=found_at
df["Origin"]=origin
df["Via"]=via

# %%
dd=df.drop_duplicates(keep="first")

# %%
df
# Out:
#          Price Airline Destination Depart_Date                 Time Origin  Via
# 0       4981.0      6E         BOM  2021-04-16  2021-04-09T16:16:36    AGR    1
# 1       7559.0      6E         MAA  2021-04-11  2021-04-10T11:43:33    AGR    1
# 2      32660.0      AF         MOW  2021-04-20  2021-04-11T17:57:33    AGR    2
# 3       7417.0      G8         VNS  2021-04-14  2021-04-09T13:58:52    AGR    2
# 4       4981.0      6E         BOM  2021-04-16  2021-04-09T16:16:36    AGR    1
# ...        ...     ...         ...         ...                  ...    ...  ...
# 42007   2331.0      SG         HYD  2021-04-14  2021-04-11T07:52:22    TIR    0
# 42008   9754.0      SG         KNU  2021-06-11  2021-04-11T03:50:52    TIR    2
# 42009   7338.0      AI         LKO  2021-06-11  2021-04-11T03:49:34    TIR    1
# 42010  11708.0      AI         NDC  2021-04-15  2021-04-10T13:09:48    TIR    2
# 42011   5095.0      6E         VTZ  2021-06-01  2021-04-08T04:44:27    TIR    1
#
# ...

# %%
dd
# Out:
#          Price Airline Destination Depart_Date                 Time Origin  Via
# 0       4981.0      6E         BOM  2021-04-16  2021-04-09T16:16:36    AGR    1
# 1       7559.0      6E         MAA  2021-04-11  2021-04-10T11:43:33    AGR    1
# 2      32660.0      AF         MOW  2021-04-20  2021-04-11T17:57:33    AGR    2
# 3       7417.0      G8         VNS  2021-04-14  2021-04-09T13:58:52    AGR    2
# 72     51999.0      QR         BKK  2021-04-24  2021-04-06T11:54:45    DIB    3
# ...        ...     ...         ...         ...                  ...    ...  ...
# 41888   2331.0      SG         HYD  2021-04-14  2021-04-11T07:52:22    TIR    0
# 41889   9754.0      SG         KNU  2021-06-11  2021-04-11T03:50:52    TIR    2
# 41890   7338.0      AI         LKO  2021-06-11  2021-04-11T03:49:34    TIR    1
# 41891  11708.0      AI         NDC  2021-04-15  2021-04-10T13:09:48    TIR    2
# 41892   5095.0      6E         VTZ  2021-06-01  2021-04-08T04:44:27    TIR    1
#
# ...

# %%
df.to_csv("final_data.csv")

# %%
import pandas as pd
import requests
df = pd.read_csv("/content/IATA_data - code.csv")
data=[]
for j in df['Code']:
  for i in range(10,31):
    url='https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsedates/v1.0/%7BIN%7D/%7BINR%7D/%7Ben-US%7D/%7BBOM%7D/%7BDEL%7D/%7Boutboundpartialdate%7D/%7Binboundpartialdate%7D'
    response = requests.request("GET", url).json()
    data.append(response)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-0f5f0f2daddb> in <module>()
#       1 import pandas as pd
#       2 import requests
# ----> 3 df = pd.read_csv("/content/IATA_data - code.csv")
#       4 data=[]
#       5 for j in df['Code']:
#
# ...

# %%
import requests
url="https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsedates/v1.0/%7BIN%7D/%7BINR%7D/%7Ben-US%7D/%7BBOM%7D/%7BDEL%7D/%7Boutboundpartialdate%7D/%7Binboundpartialdate%7D" 
response = requests.request("GET", url).json()
print(response)

# %%
#https://rapidapi.com/skyscanner/api/skyscanner-flight-search?endpoint=5aa1edd5e4b06ec3937b23f0
import requests
url="https://rapidapi.com/skyscanner/api/skyscanner-flight-search?endpoint=5aa1edd5e4b06ec3937b23f0" 
response = requests.request("GET", url).json()
print(response)

# %%
a=[1,2,3]

# %%
a[1].index()

# %%
#List Places
import requests

url ="https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/SFO-sky/ORD-sky/2021-04-11"

querystring = {"inboundpartialdate": "2021-12-01"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring).json()

print(response)

# %%
ddf=pd.read_excel("Data_Train.xlsx")

# %%
ddf.head(2)
# Out:
#      Airline Date_of_Journey    Source  ... Total_Stops Additional_Info Price
# 0     IndiGo      24/03/2019  Banglore  ...    non-stop         No info  3897
# 1  Air India       1/05/2019   Kolkata  ...     2 stops         No info  7662
#
# [2 rows x 11 columns]

# %%
dat=list(ddf["Date_of_Journey"].value_counts())

# %%
len(dat)
# Out:
# 44

# %%
ddf["Date_of_Journey"].value_counts()
# Out:
# 18/05/2019    504
# 6/06/2019     503
# 21/05/2019    497
# 9/06/2019     495
# 12/06/2019    493
# 9/05/2019     484
# 21/03/2019    423
# 15/05/2019    405
# 27/05/2019    382
# 27/06/2019    355
# 24/06/2019    351
# 1/06/2019     342
# 3/06/2019     333
# 15/06/2019    328
# 24/03/2019    323
# 6/03/2019     308
# 27/03/2019    299
# 24/05/2019    286
# 6/05/2019     282
# 1/05/2019     277
# 12/05/2019    259
# 1/04/2019     257
# 3/03/2019     218
# 9/03/2019     200
# 15/03/2019    162
# 18/03/2019    156
# 01/03/2019    152
# 12/03/2019    142
# 9/04/2019     125
# 3/04/2019     110
# 21/06/2019    109
# 18/06/2019    105
# 09/03/2019    102
# 6/04/2019     100
# 03/03/2019     97
# 06/03/2019     95
# 27/04/2019     94
# 24/04/2019     92
# 3/05/2019      90
# 15/04/2019     89
# 21/04/2019     82
# 18/04/2019     67
# 12/04/2019     63
# 1/03/2019      47
# Name: Date_of_Journey, dtype: int64

# %%
ddf.shape
# Out:
# (10683, 11)

# %%
final_data=pd.read_csv("/content/final_data_world.csv")

# %%
final_data.head()
# Out:
#    Unnamed: 0    Price Airline Destination  ... Origin Via         ttl     created
# 0           0  11317.0      TP         SPU  ...    GVA   2  1617561110  1617388310
# 1           1  14341.0      U2         CAI  ...    GVA   1  1618030110  1617857310
# 2           2   2520.0      U2         PRG  ...    GVA   0  1617902779  1617729979
# 3           3  13156.0      W6         LCA  ...    GVA   3  1617561256  1617388456
# 4           4  12464.0      TB         ALG  ...    GVA   2  1617605757  1617432957
#
# [5 rows x 10 columns]

# %%
final_data.shape
# Out:
# (72989, 10)

# %%
dd=final_data.drop_duplicates(keep="first")

# %%
dd
# Out:
#        Unnamed: 0    Price Airline  ... Via         ttl     created
# 0               0  11317.0      TP  ...   2  1617561110  1617388310
# 1               1  14341.0      U2  ...   1  1618030110  1617857310
# 2               2   2520.0      U2  ...   0  1617902779  1617729979
# 3               3  13156.0      W6  ...   3  1617561256  1617388456
# 4               4  12464.0      TB  ...   2  1617605757  1617432957
# ...           ...      ...     ...  ...  ..         ...         ...
# 72984       72984  53760.0      SU  ...   2  1618019065  1617846265
# 72985       72985  50611.0      SU  ...   1  1618034284  1617861484
# 72986       72986  54313.0      SU  ...   2  1617961205  1617788405
# 72987       72987  53340.0      SU  ...   2  1617863798  1617690998
# 72988       72988  65565.0      IO  ...   2  1618019061  1617846261
#
# [72989 rows x 10 columns]

# %%
final_data["Origin"].value_counts()
# Out:
# MSQ    500
# LED    500
# IEV    500
# IST    500
# SVX    492
#       ...
# CZU      1
# YWL      1
# UEL      1
# ENA      1
# NGK      1
# Name: Origin, Length: 2149, dtype: int64
